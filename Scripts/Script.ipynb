# %% [markdown]
# # Importar librerias

# %%
import deepl
import pandas as pd
import os

# %% [markdown]
# # Abrir dialogos originales

# %%
df = pd.read_csv("../Rinnes_Utopia_files/Originales/1st/day01_01a.tsv", delimiter="\t")
df.head()
# Out:
#   Operator Comment                                                Key  \
# 0  Message     NaN  (...How strange. How can the memory of a\r\nwo...
# 1  Message     NaN                 (Did something happen to Eden...?)
# 2  Message     NaN  (Was the reset incomplete? Or were all of\r\nt...
# 3  Message     NaN  (There's a chance that this might cause an\r\n...
# 4  Message     NaN             (No, that can't happen. It mustn't...)
#
#    Translation
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# # Crear lista con los dialogos

# %%
Dialogos = df['Key']

# %% [markdown]
# # Traducir dialogos con deepl

# %% [markdown]
# # !!Don't Touch!!

# %%
auth_key = "inserta_tu_token_de_la_api_deepl"
translator = deepl.Translator(auth_key)

# %% [markdown]
# # Obtener Lista con los dialogos

# %%
Dialogos_Traducidos = []

for i in Dialogos:
    result = translator.translate_text(str(i), target_lang="ES")
    Dialogos_Traducidos.append(result)
    print(result.text)
# Out:
# (Espíritus... Supuestamente son seres que
# no deberían existir).
# (Cuando un Espíritu aparece en el mundo, se produce involuntariamente un
# se produce involuntariamente).
# (Como su nombre indica, es un terremoto en el
# el espacio. Una fuerza masiva se abate sobre la región,
# explota, dejando nada más que un cráter humeante).
# (Se observó por primera vez hace 30 años...)
# (El centro de Eurasia desapareció; más de 150 millones
# en la mayor calamidad de la historia de la humanidad.
# de la humanidad. También conocido como el Desastre del Cielo de Eurasia).
# (Al igual que al principio,
# pequeños terremotos espaciales comenzaron a ocurrir
# en todo el mundo).
# (Por eso los Espíritus que las causan son
# conocidos como heraldos del desastre, ganándose la
# la ira y el miedo de la gente que les rodea).
# (La ciudad en la que vivimos, Tengu City, fue una vez
# el lugar de tal evento. En ese lugar, una ciudad
# fue construida para probar la última tecnología).
# (Llevaba una vida normal y corriente
# normal cuando ella llegó).
# (Las vacaciones de primavera habían terminado, y mi vida como
# segundo año comenzó el 10 de abril. En ese día,
# conocí a mi primer Spirit).
# (Lo recuerdo como si fuera ayer).
# (La ciudad fue destruida, y había un enorme
# cráter en el suelo como si hubiera caído un meteorito.
# En el centro de todo, estaba ella).
# (No podía dejar de mirarla. Ella había tomado
# mi corazón en un instante. Era tan hermosa,
# casi de otro mundo...)
# (Sus poderes podían destruir el mundo
# mundo, y debido a eso, fue vilipendiada y
# atacada por los humanos. Luchó en su desesperación).
# (Simplemente no me atrevía a pensar que ella
# era el enemigo del mundo. No sólo eso, quería
# salvarla de su tristeza).
# (Y mi deseo se hizo realidad de la forma más extraña).
# (Una organización secreta formada para proteger a los
# Espíritus. Kotori, Comandante de Ratatoskr, me habló
# de mi habilidad para sellar los poderes de los Espíritus).
# (Si tiene éxito, entonces yo sería capaz de salvar a los
# Espíritus... Sin embargo, los medios para hacerlo eran
# chocante por decir lo menos...)
# (Era para enamorar a los Espíritus.
# En otras palabras...)
# (Necesitaba pasar tanto tiempo con ellos
# y ganarme su afecto).
# (Con la ayuda de Kotori y los miembros de
# Ratatoskr, comencé mis interacciones con los
# Espíritus...)
# (Pude salvar a Tohka, Yoshino... y Kotori,
# que recuperó sus poderes para protegerme).
# (Los padres de Origami fueron asesinados por un Espíritu cinco
# años atrás. Ella no aprobaba mis acciones.
# Sin embargo, poco a poco ha ido comprendiéndome).
# (Hubo un Spirit al que no pude salvar. Una chica que
# transferido a mi escuela sin ocultar que ella
# era un Espíritu. Una chica con el pelo negro... Kurumi.)
# (En cuanto a ella, había un montón de casos que
# me hicieron dudar de ella. Ni Tohka ni Yoshino
# tenían mala voluntad hacia nadie).
# (Sin embargo, Kurumi era diferente. Kurumi mataba
# a la gente por su propia voluntad).
# (Después de escuchar esto de Tohka, decidí salvar a
# Kurumi una vez más).
# (Kurumi era el otro yo... Afirmó que si
# no me hubiera conocido y se hubiera quedado sola en su
# sufrimiento, se habría vuelto loca...)
# (Lo que Kurumi hizo fue algo
# que no se puede perdonar así como así.)
# (Pero incluso si ese fuera el caso, yo quería ser
# el que pudiera perdonarla. Quería darle
# la oportunidad de empezar de nuevo).
# (Pero mi deseo no se hizo realidad. Kurumi fue derrotada
# por Kotori, y desapareció...)
# (Durante ese tiempo, conocí a una chica que decía ser mi
# verdadera hermana pequeña, Mana Takamiya. Herida durante
# la batalla con Kurumi, está en el hospital...)
# (Tohka, Yoshino, Kurumi, Kotori, y Origami
# (aunque no es un espíritu). Desde que las conocí
# ellos, yo...)
# (¿Hm? ¿Quién era ese... Uh...?)
# (¡¿Hm?! Creo que ella estaba...
# ¡Así es! ¡Esa chica!)
# ...¿estaba soñando...?
# (Me desperté, pero todavía no podía distinguir
# la realidad del sueño. Una extraña sensación
# y fluida...)
# (La chica que vi al final...)
# (Volví a pensar en la chica que parecía de la familia
# pero a la que no podía reconocer. Me cambié y
# me dirigí al salón).
# ¡Shido, llegas tarde! ¿Cuándo es el desayuno?
# Perdón, perdón... Espera, ¿eh?
# Yoo-hoo, Shido-kun. ¿Dormiste bien?
# Buenos días. ¡Shido-san...!
# Buenos días... ¿Por qué están ustedes dos aquí...?
# ¿Qué, ya lo olvidaste? Te dije que después
# su chequeo vendrían a vivir con nosotros hasta que
# la Mansión de los Espíritus estuviera arreglada.
# O-Oh cierto, supongo que dijiste
# algo así...
# Probablemente es hora de un escáner cerebral en el hospital,
# aunque no estoy seguro de si la máquina puede leer
# telarañas.
# Ngh... H-Hey, no me culpes. Mi cabeza todavía se siente
# borrosa. No estoy en mi mejor momento.
# Quizá sea porque estuviste haciendo algo hasta
# tarde anoche con Tobiichi Origami.
# ¡No hice nada con ella! ¡Tú lo sabes!
# Sí. Supongo que nunca he considerado que usted
# podrías hacer algo en absoluto.
# Uf...
# ¿Hm? Shido... ¿Pasó algo entre tú y
# Origami Tobiichi ayer?
# No ha pasado nada. ¡No te preocupes, Tohka!
# ¿Seguro?
# S-Sí, ¡estoy seguro!
# Vale, ¡siempre que estés bien!
# ¿Shido?
# ¿Qué? ¡¿Qu-Qué pasa?!
# Ya expliqué esto ayer, pero los Espíritus son
# actualmente muy inestables.
# Si siguen enloqueciendo sin poder
# controlarse, Dios sabe qué tipo de
# bajas podríamos sufrir.
# Así que ten cuidado con lo que dices o haces.
# Sí, lo sé.
# Mientras lo sepas.
# (Kotori tiene razón. Tengo que tener cuidado.)
# ¡Muy bien, vamos a desayunar!
# Llegaremos tarde.
# ¡Sí! ¡Desayuno!
# Hace tiempo que no tomo
# tu desayuno, Shido.
# Oye Kotori, ¿tú también estás aturdida? Siempre hago...
# ¿Hm? Oh, es verdad. Normalmente-
# ¡¿Shido?! ¡¿Ya está listo?!
# Sí, muy bien. Ya casi termino.
# ¡Shido, date prisa!
# No me apures. ¡Ya casi termino!
# (Con el hambriento Tohka ya satisfecho, pudimos
# terminar el desayuno. Me dirigí hacia la puerta,
# emocionado por ir a la escuela.)
# Vale, Yoshino, ¿puedes quedarte en casa?
# ¡Vale...!
# Shido-kuuuun, ten cuidado, ¿vale? Te acabas de recuperar, así que no te presiones.
# De acuerdo, tendré cuidado.
# ¡Más tarde!
# ¡Que tenga un buen día...!
# ¡Shido, eres lento!
# ¡Lo siento!
# Dios, ¿qué estabas haciendo?
# Les pedí a Yoshino y Yoshinon
# que se ocuparan de la casa.
# Ya veo. Asegúrate de acelerarlo la próxima vez.
# Tendré cuidado. Vamos... ¡Oye, espera!
# ¿Hm?
# ¿Cuál es el problema?
# ¿Qué es eso...?
# Esa gran torre...
# ¿Qué? ¿Tan rara es la Torre Neo Tengu?
# ¿Eh...? O-Oh, nada... Es que...
# (Ante mí se alzaban las casas y paisajes habituales a los que estaba acostumbrado.
# estaba acostumbrado. Pero más allá, en el centro de la
# la ciudad, se alzaba este edificio de forma anormal).
# (Se destacaba tan obviamente de los edificios
# a su alrededor, casi como si fuera de otro
# mundo...)
# Eh, Shido. ¿Lo dices en serio? No hay muchas
# veces que puedo bromear sobre llamar a una ambulancia
# por ti.
# No puedo creer que olvidaras el nuevo símbolo...
# símbolo de nuestra ciudad. La Torre Neo Tengu.
# ¿Torre Neo Tengu...? ¿Esa cosa?
# Se acaba de terminar y sigue siendo un tema candente.
# Supuestamente, se abrirá en agosto.
# ¿En serio...?
# (¿Existió realmente esta cosa? No me acuerdo
# recuerdo... Más bien, es imposible que no me
# notar un edificio como ese).
# ¡Shido!
# (Alguien me llamó por mi nombre, y me di la vuelta
# para ver a una chica de pie allí.)
# ¡Oh! U-Um...
# ¿Shido? ¿Qué te pasa?
# N-No... Lo siento. ¡Buenos días, Rinne!
# ¡¿Eh...?!
# Cielos, Rinne-oneechan, ¿qué te pasa?
# Oh... N-Nada de nada.
# Buenos días, Shido, Kotori-chan.
# Sí.
# Rinne, ¡buenos días!
# Jeje. Buenos días, Tohka-chan.
# (¿Me lo acabo de imaginar...? Por una fracción de segundo...
# sentí que me había olvidado de Rinne...)
# (Rinne Sonogami. Ella es casi tan cercana a mí como
# Kotori es.)
# (Rinne vive al lado, y hemos sido compañeros de clase
# desde que éramos pequeños).
# (También hemos estado juntos todo ese tiempo.
# Nuestros padres se llevaban bien, así que era natural
# que ella estuviera siempre cerca).
# (No sé si sentirme patética o simplemente
# agradecido, pero hasta que conocí a Origami o Tohka,
# Rinne era mi única amiga femenina...)
# (Como mis padres siempre estaban fuera de la ciudad, Rinne
# pasaba cada mañana a prepararnos el desayuno a Kotori
# y a mí. Incluso nos ayuda con la limpieza y la colada).
# (En otras palabras, es como de la familia. Y una muy
# preciosa amiga de la infancia).
# (Para olvidarla... Hombre, todavía debo
# estar fuera de mí...)
# Eh, ¿Shido? Estás perdiendo el tiempo otra vez. Si te
# enfermo, deberías descansar más.
# Sí, tal vez no estoy de vuelta al 100% todavía.
# Pero ahora estoy bien.
# Será mejor que tengas cuidado. Si te pones enfermo en
# el verano, realmente puede prolongarse por un tiempo.
# Sí, gracias.
# ¿Eh...? U-Um... Eres, um...
# Eh, Shido... ¿De verdad estás bien?
# ¿Eh?
# Rinne, ¡buenos días!
# Jeje. Buenos días, Tohka-chan, Kotori-chan.
# ¡Buenos días, Rinne-oneechan!
# ¿R-Rinne...?
# Buenos días, Shido... Te he estado esperando
# bastante tiempo.
# Shido, buenos días. Si te tomas tu tiempo así...
# así, me cansaré de esperar.
# (...?!)
# (E-Eso es... ¿Cómo podría olvidarlo...?)
# (Rinne Sonogami-Ella es casi tan cercana
# a mí como Kotori).
# (Rinne vive al lado, y hemos sido compañeros de clase
# desde que éramos pequeños).
# (También hemos estado juntos todo ese tiempo.
# Nuestros padres se llevaban bien, así que era natural
# que ella estuviera siempre cerca).
# (No sé si sentirme patética o simplemente
# agradecido, pero hasta que conocí a Origami o Tohka,
# Rinne era mi única amiga femenina...)
# (Mis padres siempre fuera de la ciudad, Rinne se
# pasaba cada mañana a prepararnos el desayuno a Kotori
# y a mí. Incluso nos ayuda con la limpieza y la colada).
# (En otras palabras, es como de la familia. Y una muy
# preciosa amiga de la infancia).
# Shido, si todavía te sientes mal, tal vez...
# deberías seguir descansando.
# Sabes, tal vez no estoy en mi mejor momento todavía.
# ...pero estoy bien. No te preocupes.
# Será mejor que tengas cuidado. Si te pones enfermo en
# el verano, realmente puede prolongarse por un tiempo.
# Sí, gracias...
# ¡Oh...!
# ¿Qué pasa, Rinne?
# Eh, ¿Shido? Creo que he notado algo
# que no debería haber...
# ¿Eh?
# Sí, bueno, siento que tal vez no es bueno.
# No lo alargues...
# Um... Tal vez hablamos demasiado.
# Vamos a llegar tarde.
# ¿Eh? ¡¿Qué?! ¡¿Por qué no lo dijiste, Rinne?!
# ¡Corramos!
# ¡Vale!
# ¡Venga! Tohka, Kotori, ¡vamos!
# ¡Sh-Shido! ¡Esperad!
# (Y así fue como mi vida en la escuela
# empezó de nuevo).
# (Mis días con Tohka, Yoshino, Kotori, Origami...
# y Rinne).
# (Hoy sería el comienzo de otro día).

# %% [markdown]
# # Agregar dialogos con los traducidos

# %%
for i in range(0,len(Dialogos_Traducidos)):
    df.iloc[i,3] = str(Dialogos_Traducidos[i])
df.head()
# Out:
# C:\Users\Christian\AppData\Local\Temp\ipykernel_9148\335883297.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '(Espíritus... Supuestamente son seres que
# no deberían existir).' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.iloc[i,3] = str(Dialogos_Traducidos[i])
#   Operator Comment                                                Key  \
# 0  Message     NaN  (Spirits... Supposedly they are beings that\r\...
# 1  Message     NaN  (When a Spirit appears in the world, a spacequ...
# 2  Message     NaN  (As the name implies, it's an earthquake in\r\...
# 3  Message     NaN            (It was first observed 30 years ago...)
# 4  Message     NaN  (Eurasia's center disappeared; over 150 millio...
#
#                                          Translation
# 0  (Espíritus... Supuestamente son seres que\r\nn...
# 1  (Cuando un Espíritu aparece en el mundo, se pr...
# 2  (Como su nombre indica, es un terremoto en el\...
# 3       (Se observó por primera vez hace 30 años...)
# 4  (El centro de Eurasia desapareció; más de 150 ...

# %% [markdown]
# # Exportar a .TSV

# %%
ruta_guardado = "../Rinnes_Utopia_files/Traducidos/1st/day01_01a.tsv"
df.to_csv(ruta_guardado, sep="\t", index=False)

# %% [markdown]
# # END ------------------------------------------------------------
